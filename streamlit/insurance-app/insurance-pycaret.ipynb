# %%
import pandas as pd

# %%
data = pd.read_csv('../../data/insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *

# %%
r2 = setup(data, target='charges', session_id=123, normalize=True, trigonometry_features=True, polynomial_features=True,
          feature_interaction=True, bin_numeric_features=['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
# #T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow15_col1,#T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow25_col1,#T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow32_col1,#T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow34_col1,#T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow39_col1{
#             background-color:  yellow;
#         }</style><table id="T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2ced" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6d2201e_4cc5_11eb_a3d2_e45e37cb2cedrow0_col0" class="data row0 col0" >session_id</td>
# ...

# %%
lr = create_model('lr')
# Out:
# <style  type="text/css" >
# #T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col0,#T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col1,#T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col2,#T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col3,#T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col4,#T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedrow10_col5{
#             background:  yellow;
#         }</style><table id="T_2897bf0a_4cc6_11eb_80f8_e45e37cb2ced" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2897bf0a_4cc6_11eb_80f8_e45e37cb2cedlevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
plot_model(lr, plot='residuals')

# %%
save_model(lr, model_name='deployment_01012021')
# Out:
# Transformation Pipeline and Model Succesfully Saved
